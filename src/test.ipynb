# %%
import sys
import os

SRC_PATH = os.path.abspath(os.path.join("..", "src"))
sys.path.append(SRC_PATH)

# %%
from pydq.check_set import CheckSetConfig
from pydq.checks.row_checks_config import *
from pydq.checks.aggregate_check_config import *

# %%
ch = DateBetweenCheck(id='a', columns=['a', ''], min_value='1999-12-12', max_value='1999-12-12', inclusive=('a', 'b'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ch = DateBetweenCheck(id='a', columns=[], min_value='1999-12-12', max_value='1999-12-12', inclusive=('a', 'b'))
#
# File <string>:10, in __init__(self, id, severity, description, columns, min_value, max_value, inclusive)
#
# File c:\Users\jufcamac\Documents\repos\MLOps\sparkdq-wrapper\src\pydq\checks\row_checks_config.py:53, in DateBetweenCheck.__post_init__(self)
#      51 def __post_init__(self):
#      52     super().__post_init__()
# ---> 53     self._validate_columns(value=self.columns)
#      54     self._require_date(self.min_value, 'min_value')
#      55     self._require_date(self.max_value, 'max_value')
#
# File c:\Users\jufcamac\Documents\repos\MLOps\sparkdq-wrapper\src\pydq\checks\base_check_config.py:86, in CheckConfig._validate_columns(value)
#      84 else:
# ...
